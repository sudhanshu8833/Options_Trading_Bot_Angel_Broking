# %%
from datetime import date

import pandas as pd
import time
import sys

# local modules
from binance.client import Client
from binance.enums import *
from indicator import indicators

# local file
import secrets
from configparser import ConfigParser
import yfinance as yf
import numpy as np
import datetime as dt
import requests 
import json 
import pandas as pd 
import numpy as np  
from finta import TA

# %%
import telepot
bot = telepot.Bot('1715056219:AAGxytb3U1gIt1vlVn8Jf5b4za3E1HPuOd4')
bot.getMe()
# Out:
# {'id': 1715056219,
#  'is_bot': True,
#  'first_name': 'trading bot',
#  'username': 'trading_112_bot',
#  'can_join_groups': True,
#  'can_read_all_group_messages': False,
#  'supports_inline_queries': False}

# %%
df3 = pd.read_csv("parameters.csv")
df3.set_index("parameters",inplace=True)
df1=df3.T

# %%
client = Client((df1['binance_api_key'][0]), str(df1['binance_api_secret_key'][0]))

# %%
def candle(symbol, interval):


    root_url = 'https://api.binance.com/api/v1/klines'
    url = root_url + '?symbol=' + symbol + '&interval=' + interval
    data = json.loads(requests.get(url).text)
    df = pd.DataFrame(data)
    df.columns = ['Datetime',
                'Open', 'High', 'Low', 'Close', 'volume',
                'close_time', 'qav', 'num_trades',
                'taker_base_vol', 'taker_quote_vol', 'ignore']
    df.index = [dt.datetime.fromtimestamp(x / 1000.0) for x in df.close_time]
    print(df)
    df.drop(['close_time','qav','num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'],axis=1,inplace=True)
           
    
    df['Open']=pd.to_numeric(df["Open"], downcast="float")
    df["High"]=pd.to_numeric(df["High"], downcast="float")
    df["Low"]=pd.to_numeric(df["Low"], downcast="float")
    df["Close"]=pd.to_numeric(df["Close"], downcast="float")
    df["volume"]=pd.to_numeric(df["volume"], downcast="float")


    atr1='FIXED_ATR'
    df[atr1]=TA.ATR(df,int(df1['atr_fixed'][0]))
    df['X_BARS_HIGH']=df['High'][-int(df1['X_bars_high'][0]):-1].max()
    df['X_BARS_LOW']=df['Low'][-int(df1['X_bars_low'][0]):-1].min()

    atr=TA.ATR(df,int(df1['atr_trailing'][0]))
    

    df['TRAILING_ATR']=TA.ATR(df,int(df1['atr_trailing'][0]))
    

    return df

# %%
candle('BTCUSDT','5m')
# Out:
#                               Datetime            Open            High  \
# 2021-08-21 05:59:59.999  1629505500000  48952.55000000  49010.00000000
# 2021-08-21 06:04:59.999  1629505800000  48825.99000000  48972.69000000
# 2021-08-21 06:09:59.999  1629506100000  48918.47000000  49009.06000000
# 2021-08-21 06:14:59.999  1629506400000  48914.27000000  49041.39000000
# 2021-08-21 06:19:59.999  1629506700000  48984.48000000  49061.63000000
# ...                                ...             ...             ...
# 2021-08-22 23:14:59.999  1629654000000  48591.35000000  48609.86000000
# 2021-08-22 23:19:59.999  1629654300000  48592.13000000  48647.37000000
# 2021-08-22 23:24:59.999  1629654600000  48612.63000000  48642.63000000
# 2021-08-22 23:29:59.999  1629654900000  48566.41000000  48693.23000000
# 2021-08-22 23:34:59.999  1629655200000  48677.29000000  48677.29000000
#
#                                     Low           Close        volume  \
# 2021-08-21 05:59:59.999  48800.01000000  48825.98000000  324.31784300
# 2021-08-21 06:04:59.999  48713.50000000  48917.12000000  452.95473400
# 2021-08-21 06:09:59.999  48907.00000000  48914.26000000  121.16205400
# 2021-08-21 06:14:59.999  48910.73000000  48984.49000000  132.70922100
# 2021-08-21 06:19:59.999  48964.91000000  48964.92000000  113.19061000
# ...                                 ...             ...           ...
# 2021-08-22 23:14:59.999  48542.69000000  48592.14000000   63.31561000
# 2021-08-22 23:19:59.999  48550.00000000  48608.27000000   83.89070700
# 2021-08-22 23:24:59.999  48562.97000000  48566.40000000   66.79419800
# 2021-08-22 23:29:59.999  48565.77000000  48677.28000000   64.62963800
# 2021-08-22 23:34:59.999  48573.01000000  48585.19000000   41.93960800
#
#                             close_time                qav  num_trades  \
# 2021-08-21 05:59:59.999  1629505799999  15859919.89602069       17346
# 2021-08-21 06:04:59.999  1629506099999  22124412.18831857       19397
# 2021-08-21 06:09:59.999  1629506399999   5933346.93256215       13305
# 2021-08-21 06:14:59.999  1629506699999   6501464.70702619       12073
# 2021-08-21 06:19:59.999  1629506999999   5549076.70238709       12642
# ...                                ...                ...         ...
# 2021-08-22 23:14:59.999  1629654299999   3075214.07340641        2540
# 2021-08-22 23:19:59.999  1629654599999   4077206.64935157        2973
# 2021-08-22 23:24:59.999  1629654899999   3246102.38238762        2726
# 2021-08-22 23:29:59.999  1629655199999   3142984.55125101        2670
# 2021-08-22 23:34:59.999  1629655499999   2039314.05008314        2233
#
#                         taker_base_vol    taker_quote_vol ignore
# 2021-08-21 05:59:59.999   132.63410300   6486822.78023926      0
# 2021-08-21 06:04:59.999   256.47562800  12531430.03131340      0
# 2021-08-21 06:09:59.999    55.37506700   2711765.42611791      0
# 2021-08-21 06:14:59.999    62.60879500   3067537.00393679      0
# 2021-08-21 06:19:59.999    52.26143100   2562206.14170530      0
# ...                                ...                ...    ...
# 2021-08-22 23:14:59.999    31.29517500   1519926.13944874      0
# 2021-08-22 23:19:59.999    39.99306000   1943881.77972724      0
# 2021-08-22 23:24:59.999    33.60661000   1633366.11880550      0
# 2021-08-22 23:29:59.999    35.45933500   1724479.28403001      0
# 2021-08-22 23:34:59.999    13.92790300    677288.45377603      0
#
# [500 rows x 12 columns]
#                               Datetime          Open          High  \
# 2021-08-21 05:59:59.999  1629505500000  48952.550781  49010.000000
# 2021-08-21 06:04:59.999  1629505800000  48825.988281  48972.691406
# 2021-08-21 06:09:59.999  1629506100000  48918.468750  49009.058594
# 2021-08-21 06:14:59.999  1629506400000  48914.269531  49041.390625
# 2021-08-21 06:19:59.999  1629506700000  48984.480469  49061.628906
# ...                                ...           ...           ...
# 2021-08-22 23:14:59.999  1629654000000  48591.351562  48609.859375
# 2021-08-22 23:19:59.999  1629654300000  48592.128906  48647.371094
# 2021-08-22 23:24:59.999  1629654600000  48612.628906  48642.628906
# 2021-08-22 23:29:59.999  1629654900000  48566.410156  48693.230469
# 2021-08-22 23:34:59.999  1629655200000  48677.289062  48677.289062
#
#                                   Low         Close      volume   FIXED_ATR  \
# 2021-08-21 05:59:59.999  48800.011719  48825.980469  324.317841         NaN
# 2021-08-21 06:04:59.999  48713.500000  48917.121094  452.954742         NaN
# 2021-08-21 06:09:59.999  48907.000000  48914.261719  121.162056         NaN
# 2021-08-21 06:14:59.999  48910.730469  48984.488281  132.709229         NaN
# 2021-08-21 06:19:59.999  48964.910156  48964.921875  113.190613         NaN
# ...                               ...           ...         ...         ...
# 2021-08-22 23:14:59.999  48542.691406  48592.140625   63.315609  116.780599
# 2021-08-22 23:19:59.999  48550.000000  48608.269531   83.890709  114.675781
# 2021-08-22 23:24:59.999  48562.968750  48566.398438   66.794197  107.502604
# 2021-08-22 23:29:59.999  48565.769531  48677.281250   64.629639  107.740234
# 2021-08-22 23:34:59.999  48573.011719  48585.191406   41.939610  108.434896
#
#                          X_BARS_HIGH  X_BARS_LOW  TRAILING_ATR
# 2021-08-21 05:59:59.999      49500.0     48050.0           NaN
# 2021-08-21 06:04:59.999      49500.0     48050.0           NaN
# 2021-08-21 06:09:59.999      49500.0     48050.0           NaN
# 2021-08-21 06:14:59.999      49500.0     48050.0           NaN
# 2021-08-21 06:19:59.999      49500.0     48050.0           NaN
# ...                              ...         ...           ...
# 2021-08-22 23:14:59.999      49500.0     48050.0    112.223307
# 2021-08-22 23:19:59.999      49500.0     48050.0    108.566406
# 2021-08-22 23:24:59.999      49500.0     48050.0     96.738281
# 2021-08-22 23:29:59.999      49500.0     48050.0     93.448568
# 2021-08-22 23:34:59.999      49500.0     48050.0     89.110026
#
# [500 rows x 10 columns]

# %%
len(candle('BTCUSDT','5m'))
# Out:
#                               Datetime            Open            High  \
# 2021-08-21 05:59:59.999  1629505500000  48952.55000000  49010.00000000
# 2021-08-21 06:04:59.999  1629505800000  48825.99000000  48972.69000000
# 2021-08-21 06:09:59.999  1629506100000  48918.47000000  49009.06000000
# 2021-08-21 06:14:59.999  1629506400000  48914.27000000  49041.39000000
# 2021-08-21 06:19:59.999  1629506700000  48984.48000000  49061.63000000
# ...                                ...             ...             ...
# 2021-08-22 23:14:59.999  1629654000000  48591.35000000  48609.86000000
# 2021-08-22 23:19:59.999  1629654300000  48592.13000000  48647.37000000
# 2021-08-22 23:24:59.999  1629654600000  48612.63000000  48642.63000000
# 2021-08-22 23:29:59.999  1629654900000  48566.41000000  48693.23000000
# 2021-08-22 23:34:59.999  1629655200000  48677.29000000  48677.29000000
#
#                                     Low           Close        volume  \
# 2021-08-21 05:59:59.999  48800.01000000  48825.98000000  324.31784300
# 2021-08-21 06:04:59.999  48713.50000000  48917.12000000  452.95473400
# 2021-08-21 06:09:59.999  48907.00000000  48914.26000000  121.16205400
# 2021-08-21 06:14:59.999  48910.73000000  48984.49000000  132.70922100
# 2021-08-21 06:19:59.999  48964.91000000  48964.92000000  113.19061000
# ...                                 ...             ...           ...
# 2021-08-22 23:14:59.999  48542.69000000  48592.14000000   63.31561000
# 2021-08-22 23:19:59.999  48550.00000000  48608.27000000   83.89070700
# 2021-08-22 23:24:59.999  48562.97000000  48566.40000000   66.79419800
# 2021-08-22 23:29:59.999  48565.77000000  48677.28000000   64.62963800
# 2021-08-22 23:34:59.999  48573.01000000  48585.18000000   42.04953700
#
#                             close_time                qav  num_trades  \
# 2021-08-21 05:59:59.999  1629505799999  15859919.89602069       17346
# 2021-08-21 06:04:59.999  1629506099999  22124412.18831857       19397
# 2021-08-21 06:09:59.999  1629506399999   5933346.93256215       13305
# 2021-08-21 06:14:59.999  1629506699999   6501464.70702619       12073
# 2021-08-21 06:19:59.999  1629506999999   5549076.70238709       12642
# ...                                ...                ...         ...
# 2021-08-22 23:14:59.999  1629654299999   3075214.07340641        2540
# 2021-08-22 23:19:59.999  1629654599999   4077206.64935157        2973
# 2021-08-22 23:24:59.999  1629654899999   3246102.38238762        2726
# 2021-08-22 23:29:59.999  1629655199999   3142984.55125101        2670
# 2021-08-22 23:34:59.999  1629655499999   2044654.97128958        2247
#
#                         taker_base_vol    taker_quote_vol ignore
# 2021-08-21 05:59:59.999   132.63410300   6486822.78023926      0
# 2021-08-21 06:04:59.999   256.47562800  12531430.03131340      0
# 2021-08-21 06:09:59.999    55.37506700   2711765.42611791      0
# 2021-08-21 06:14:59.999    62.60879500   3067537.00393679      0
# 2021-08-21 06:19:59.999    52.26143100   2562206.14170530      0
# ...                                ...                ...    ...
# 2021-08-22 23:14:59.999    31.29517500   1519926.13944874      0
# 2021-08-22 23:19:59.999    39.99306000   1943881.77972724      0
# 2021-08-22 23:24:59.999    33.60661000   1633366.11880550      0
# 2021-08-22 23:29:59.999    35.45933500   1724479.28403001      0
# 2021-08-22 23:34:59.999    14.02332500    681924.54977621      0
#
# [500 rows x 12 columns]
# 500

# %%
def ltp_price(instrument):
    global df3
    # prices = client.get_all_tickers()
    # for i in range(len(prices)):
    #     if prices[i]['symbol']==str(instrument):
            
    #         return float(prices[i]['price'])

    return float(df3['Close'][-1])


# %%

def market_order():
    global df,df1,distance_long,distance_short,buy_price,sell_price,quantity_buy,quantity_sell,fixed_buy_atr,fixed_sell_atr
    fixed_buy_atr=float(df['FIXED_ATR'][-1])

    # p_l=balance in account
    # stoploss=df1['risk'][0]/100 * p_l
    # quantity_buy=int(stoploss/fixed_buy_atr)
    # order = client.futures_create_order(
    #     symbol=str(df2['symbol_binance'][0]),
    #     side=Client.SIDE_BUY,
    #     type=Client.ORDER_TYPE_MARKET,
       
        
    #     quantity=float(df1['quantity'][0]))

    buy_price=ltp_price(df1['symbol_binance'][0])

    l=1
    



def market_order1():
    global df,df1,distance_long,distance_short,buy_price,sell_price,quantity_buy,quantity_sell,fixed_buy_atr,fixed_sell_atr
    
    fixed_sell_atr=float(df['FIXED_ATR'][-1])


    # p_l=balance in account
    # stoploss=df1['risk'][0]/100 * p_l
    # quantity_sell=int(stoploss/fixed_buy_atr)
    
    

    # order = client.futures_create_order(
    #     symbol=str(df1['symbol_binance'][0]),
    #     side=Client.SIDE_SELL,
    #     type=Client.ORDER_TYPE_MARKET,

        
    #     quantity=float(df1['quantity'][0]))
    sell_price=ltp_price(df1['symbol_binance'][0])

    l=1

# %%
def trade_signal(instrument,l_s):
    
    global df,df1,distance_long,distance_short,buy_price,sell_price,quantity_buy,quantity_sell,fixed_buy_atr,fixed_sell_atr

    ltp=ltp_price(df1['symbol_binance'][0])

    

    signal=""
    if l_s=="":
    
        if ltp>float(df['X_BARS_HIGH'][-1]):
            signal="buy"
            fixed_buy_atr=float(df['FIXED_ATR'][-1])


        if ltp<float(df['X_BARS_LOW'][-1]):
            signal="sell"
            fixed_sell_atr=float(df['FIXED_ATR'][-1])


    elif l_s=="long":
        distance1_long=ltp-df['TRAILING_ATR'][-1]*df1['atr_trailing_multiplier'][0]
        if distance1_long>distance_long:
            distance_long=ltp-df['TRAILING_ATR'][-1]*df1['atr_trailing_multiplier'][0]
        if ltp<=buy_price-fixed_buy_atr*df1['atr_fixed_multiplier'][0] or ltp<=distance_long:
            distance_long=0


            signal="squareoffsell"


    elif l_s=="short":
        distance1_short=ltp+df['TRAILING_ATR'][-1]*df1['atr_trailing_multiplier'][0]

        if distance1_short<distance_short:
            distance_short=ltp+df['TRAILING_ATR'][-1]*df1['atr_trailing_multiplier'][0]
        if ltp>=sell_price+ fixed_sell_atr *df1['atr_fixed_multiplier'][0] or ltp>=distance_short:
            distance_short=100000000000
            
            signal="squareoffbuy"

  


    return signal

# %%
def main():
    global df,df1,distance_long,distance_short,buy_price,sell_price,quantity_buy,quantity_sell,fixed_buy_atr,fixed_sell_atr,position

    times1=time.time()
    df3 = pd.read_csv("parameters.csv")
    df3.set_index("parameters",inplace=True)
    df1=df3.T
    ltp=ltp_price(df1['symbol_binance'][0])
    
    df=candle(df1['symbol_binance'][0],str(df1['time_frame'][0]))
    df3=candle(df1['symbol_binance'][0],'1m')
    

    






    
    
    l_s=position
    signal=trade_signal(df1['symbol_binance'][0],l_s)

    
    
  


    if signal=='buy':
        market_order()
        position='long'
        bot.sendMessage(1039725953,f"New long position initiated at {buy_price}")

    if signal=='sell':
        market_order1()
        position='short'
        bot.sendMessage(1039725953,f"New short position initiated at {sell_price}")
    
    if signal=="squareoffsell":
        market_order1()
        position=''

        bot.sendMessage(1039725953,f"long position squared of at {sell_price}")
        bot.sendMessage(1039725953,f" profit of {((sell_price-buy_price)/buy_price)*100*int(df1['binance_X'][0])}")
    if signal=="squareoffbuy":
        market_order()
        position=''

        bot.sendMessage(1039725953,f"short position squared of at {buy_price}")
        bot.sendMessage(1039725953,f" profit of {((sell_price-buy_price)/buy_price)*100*int(df1['binance_X'][0])}")

# %%
l=0
distance_short=100000000000
distance_long=0
position=''

while True:
    # try:

    main()
    print("hello")
    # except Exception as e:
    #     botss=str(e)
    #     print('something is happening')
        # bot.sendMessage(1039725953,botss)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-3fd65a2ad5f2> in <module>
#       7     # try:
#       8
# ----> 9     main()
#      10     print("hello")
#      11     # except Exception as e:
#
# <ipython-input-10-c5f6a0c76203> in main()
#       6     df3.set_index("parameters",inplace=True)
#       7     df1=df3.T
# ----> 8     ltp=ltp_price(df1['symbol_binance'][0])
#       9
#      10     df=candle(df1['symbol_binance'][0],str(df1['time_frame'][0]))
#
# <ipython-input-8-ff52bb78718b> in ltp_price(instrument)
#       7     #         return float(prices[i]['price'])
#       8
# ----> 9     return float(df3['Close'][-1])
#      10
#      11
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Close'

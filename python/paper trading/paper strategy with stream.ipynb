# %%
import pandas as pd
import time
from finta import TA
import yfinance as yf
import numpy as np
import pandas as pd
import yfinance as yf
from alpha_vantage.timeseries import TimeSeries
import datetime as dt
import copy
import json
from smartapi import SmartConnect

# %%
obj=SmartConnect(api_key="iJ3YYOXH")
data = obj.generateSession("S776051","Madhya246###")
refreshToken= data['data']['refreshToken']
feedToken=obj.getfeedToken()
userProfile= obj.getProfile(refreshToken)

# %%
from smartapi import SmartWebSocket
FEED_TOKEN= feedToken
CLIENT_CODE="S776051"

ss =SmartWebSocket(FEED_TOKEN, CLIENT_CODE)

# %%
tickers=["3045",]

investment=5000
risk=50   
portfolio=30000
transaction_cost=.0075
price={}
price1={}
position={}
for ticker in tickers:
    price[ticker]=0
    price1[ticker]=0
    position[ticker]=""

ohlcv_database=pd.DataFrame()
stock=[]
profit=[]
price_in=[]
price_out=[]
order=[]
ltp=0

# %%
from smartapi import SmartConnect 
obj=SmartConnect(api_key="iJ3YYOXH")
data = obj.generateSession("S776051","Madhya246###")
refreshToken= data['data']['refreshToken']
feedToken=obj.getfeedToken()
userProfile= obj.getProfile(refreshToken)

# %%
def candle(instrument):
    ohlc_intraday=pd.DataFrame()

    

    historicParam={
    "exchange": "NSE",
    "symboltoken": instrument,
    "interval": "FIVE_MINUTE",
    "fromdate": "2021-04-08 09:15", 
    "todate": "2021-06-15 09:30"
    }

    data=obj.getCandleData(historicParam)

    data=pd.DataFrame(data)["data"]
    open=[]
    close=[]
    high=[]
    low=[]
    volume=[]
    index=[]
    for i in range(len(data)):
        open.append(data[i][1])

    for i in range(len(data)):
        close.append(data[i][4])

    for i in range(len(data)):
        high.append(data[i][2])

    for i in range(len(data)):
        low.append(data[i][3])

    for i in range(len(data)):
        index.append(data[i][0])

    for i in range(len(data)):
        volume.append(data[i][5])


    ohlc_intraday["Index"]=np.array(index)
    ohlc_intraday["Open"]=np.array(open)
    ohlc_intraday["High"]=np.array(high)
    ohlc_intraday["Low"]=np.array(low)

    ohlc_intraday["Close"]=np.array(close)
    ohlc_intraday["Volume"]=np.array(volume)
    ohlc_intraday.set_index("Index",inplace=True)

    return ohlc_intraday

# %%
def MACD(DF,a,b,c):
    """function to calculate MACD
       typical values a = 12; b =26, c =9"""
    df = DF.copy()
    df["MA_Fast"]=df["close"].ewm(span=a,min_periods=a).mean()
    df["MA_Slow"]=df["close"].ewm(span=b,min_periods=b).mean()
    df["MACD"]=df["MA_Fast"]-df["MA_Slow"]
    df["Signal"]=df["MACD"].ewm(span=c,min_periods=c).mean()

    return df

# %%
def market_order(instrument,investment,risk):
        global price,position,price_in,portfolio
        account_id = "101-002-19512089-001"
        ohlc_dict=pd.DataFrame()
        ohlc_dict=candle(instrument)
        price[instrument]=float(ltp)    
        units=round(investment/price[instrument],0)
        sl=round(risk/units,3)
        price_in.append(price[instrument])
        stock.append(instrument)
        if units>0:
                position[instrument]="long"
                order.append("long")

                portfolio=portfolio-units*price[instrument]

        if units<0:
                position[instrument]="short"
                order.append("short")
                portfolio=portfolio+abs(units*price[instrument])


        print("order filled for ",instrument)

# %%
def market_order1(instrument,investment):
        global price,price1,position,price_out,portfolio
        account_id = "101-002-19512089-001"

        ohlc_dict=pd.DataFrame()
        ohlc_dict=candle(instrument)
        price1[instrument]=float(ltp)    
        units=round(investment/price1[instrument],0)

        price_out.append(price1[instrument])
        if units>0:


                
                position[instrument]=""
                portfolio=portfolio-units*price1[instrument] - .01*abs(price[instrument]-price1[instrument])


        if units<0:
                position[instrument]=""

                portfolio=portfolio+units*price1[instrument] -.01*abs(price[instrument]-price1[instrument]) 





        print("order squared off for ",instrument)

# %%
def trade_signal(instrument,l_s):
    
    global ltp
    
    ohlc_dict=pd.DataFrame()
    ohlc_dict=candle(instrument)
    

    ohlc_dict.columns=["open","high","low","close","volume"]
    ohlc_dict["fisher 20"]=TA.FISH(ohlc_dict,20)
    ohlc_dict["fisher 10"]=TA.FISH(ohlc_dict,10)    
    ohlc_dict["RSI 16"]=TA.RSI(ohlc_dict,16)
    ohlc_dict["RSI 21"]=TA.RSI(ohlc_dict,21)
    ohlc_dict["MACD macd line"]=MACD(ohlc_dict,12,26,9)["MACD"]
    ohlc_dict["MACD signal line"]=MACD(ohlc_dict,12,26,9)["Signal"]

    signal=""
    if l_s=="":

        if ohlc_dict["fisher 10"].iloc[-1]>0 and ohlc_dict["fisher 10"].iloc[-2]<0 and ohlc_dict["RSI 16"].iloc[-1]>50: 
            signal="buy"
            
            
        
            
            



        elif (ohlc_dict["fisher 20"].iloc[-1]<0 and ohlc_dict["fisher 20"].iloc[-1-1]>0) and ohlc_dict["MACD macd line"].iloc[-1]<ohlc_dict["MACD signal line"].iloc[-1] and ohlc_dict["RSI 21"].iloc[-1]<42.5:
            signal="sell"
                        
      

    elif l_s=="long":
        if (ohlc_dict["fisher 20"].iloc[-1]<0.5 and ohlc_dict["fisher 20"].iloc[-1-1]>0.5) or ltp>=price[instrument]+.02*price[instrument] or ltp<=price[instrument]-.008*price[instrument]:

            signal="squareoffsell"
            

           
        
        
    elif l_s=="short":
        if (ohlc_dict["fisher 20"].iloc[-1]>-1 and ohlc_dict["fisher 20"].iloc[-1-1]<-1) or (ohlc_dict[ticker].iloc["fisher 20"][-1]>0 and ohlc_dict["fisher 20"].iloc[-1-1]<0) or ltp<=price[instrument]-.02*price[instrument] or ltp>=price[instrument]+.005*price[instrument]:
            

            signal="squareoffbuy"


    return signal

# %%
def long_short(instrument):
    account_id = "101-002-19512089-001"
    r=trades.OpenTrades(accountID=account_id)
    l_s=""
    open_trades=client.request(r)
  
    for i in range(len(open_trades)):
        if open_trades["trades"][i]["instrument"]==instrument and float(open_trades["trades"][i]["currentUnits"])>0:
            l_s="long"    

        elif open_trades["trades"][i]["instrument"]==instrument and float(open_trades["trades"][i]["currentUnits"])<0:
            l_s="short" 

    return l_s

# %%
def main():
    global tickers,investment,risk,ltp
    for ticker in tickers:

        var="nse_cm|"
        token=var+ticker
        task="mw" 

        def on_message(ws, message):
            
            data=format(message)
            data=data.replace("'",'"')
            data=json.loads(data)
            if data[0]["tk"]==ticker:
                ltp=float(data[0]['ltp'])
                ws.close()

           
            
        def on_open(ws):
            # print("on open")
            ss.subscribe(task,token)
            
        def on_error(ws, error):
            print(error)
            
        def on_close(ws):
            print("Close")

        # Assign the callbacks.
        ss._on_open = on_open
        ss._on_message = on_message
        ss._on_error = on_error
        ss._on_close = on_close

        ss.connect()

        print("\n \n analyzzing for ",ticker)

        l_s= position[ticker]
        print(l_s)
        signal=trade_signal(ticker,l_s)
        if signal=="buy":
            market_order(ticker,investment,risk)
            print("New long position initiated for ",ticker)

        elif signal=="sell":
            market_order(ticker,-1*investment,risk)
            print("New short position initiated for ", ticker)

        elif signal=="squareoffbuy":
            market_order1(ticker,investment)

        elif signal=="squareoffsell":
            market_order1(ticker,-1*investment)

# %%
start_time=time.time()
timeout=start_time+60*60*5
while time.time()<=timeout:
    try: 
        print("passthrough at ",time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
        main()
        # print("porfolio: ",portfolio)

        # time.sleep(300-(time.time()-start_time)%300)
        
    except KeyboardInterrupt:
        print("keyboard interuption ....... exiting")

for ticker in tickers:
    if position[ticker]=="long":
        market_order1(ticker,-1*investment)

    if position[ticker]=="short":
        market_order1(ticker,investment)
# Out:
# 6051', 'acctid': 'S776051'}
# 2021-06-14 15:53:09.878924 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:10.046549 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:10.168378 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:10.300076 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:10.500825 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:10.707006 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:13.225417 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
#
#
#  analyzzing for  3045
#
# 2021-06-14 15:53:13.248017 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:13.862187 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:14.814541 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:15.431504 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# passthrough at  2021-06-14 15:53:15
# 2021-06-14 15:53:16.110196 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# __on_open################
# {'task': 'cn', 'channel': 'NONLM', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:16.471098 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:18.092844 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:18.148052 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:18.275711 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
#
#
#  analyzzing for  3045
#
# 2021-06-14 15:53:18.374238 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:18.783245 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:19.264412 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# passthrough at  2021-06-14 15:53:20
# 2021-06-14 15:53:20.881717 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# __on_open################
# {'task': 'cn', 'channel': 'NONLM', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:21.264888 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:22.040147 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:23.133360 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:23.427088 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:24.506520 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:24.808235 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:25.306467 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:25.556383 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
#
#
#  analyzzing for  3045
#
# 2021-06-14 15:53:27.273954 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:27.538885 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:28.373811 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:28.894123 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:28.951364 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# passthrough at  2021-06-14 15:53:29
# __on_open################
# {'task': 'cn', 'channel': 'NONLM', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:29.938044 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:30.031964 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:30.070044 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:30.317113 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:31.262093 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:31.683938 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:33.240630 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:33.520728 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:34.477631 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:34.791246 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:34.862032 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:34.889250 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:35.054882 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:35.758491 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:37.078839 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:37.220265 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:37.411966 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:37.973122 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
#
#
#  analyzzing for  3045
#
# 2021-06-14 15:53:38.960154 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:39.146153 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:39.889378 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# passthrough at  2021-06-14 15:53:40
# 2021-06-14 15:53:40.050580 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:40.170838 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:40.302729 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# __on_open################
# {'task': 'cn', 'channel': 'NONLM', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:40.496527 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:40.504583 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:40.711574 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:43.230096 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:43.252700 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:43.866214 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:44.819249 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:45.431594 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
#
#
#  analyzzing for  3045
#
# 2021-06-14 15:53:46.114379 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:46.475123 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# passthrough at  2021-06-14 15:53:47
# 2021-06-14 15:53:48.096827 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:48.153158 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:48.280030 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# __on_open################
# {'task': 'cn', 'channel': 'NONLM', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:48.334225 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:48.377942 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:48.785769 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:49.269130 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:50.885540 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:51.268740 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:52.046824 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:53.138592 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:53.432501 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:54.514051 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:54.813965 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:55.312411 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:55.560749 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:57.277033 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:53:57.538556 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# Error info:
#
#
#
#  analyzzing for  3045
#
# 2021-06-14 15:53:58.376244 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:58.897149 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:58.955297 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:53:59.942870 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:00.034928 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:00.069952 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:00.328754 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# passthrough at  2021-06-14 15:54:00
# __on_open################
# {'task': 'cn', 'channel': 'NONLM', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:01.018998 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:01.263618 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:01.687728 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# Error info:
#
#
#
#  analyzzing for  3045
#
# 2021-06-14 15:54:03.245288 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:03.521428 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:04.481195 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:04.793476 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:04.863463 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:04.892492 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# 2021-06-14 15:54:05.059213 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# passthrough at  2021-06-14 15:54:05
# 2021-06-14 15:54:05.763431 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# HeartBeat Sending Failed
# __on_open################
# {'task': 'cn', 'channel': 'NONLM', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:05.895097 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:07.080468 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:07.225703 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:07.414980 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:07.976535 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:08.964610 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:09.149542 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:09.924700 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:10.053243 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:10.172275 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:10.303253 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:10.500845 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:10.509195 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}
# 2021-06-14 15:54:10.713221 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '0950688964', 'user': 'S776051', 'acctid': 'S776051'}

# %%
ohlcv_database["price_in"]=np.array(price_in)
ohlcv_database["price_out"]=np.array(price_out)
ohlcv_database["order"]=np.array(order)
ohlcv_database["stock"]=np.array(stock)
